# %%
import pandas as pd
from carps.analysis.gather_data import normalize_logs, get_interpolated_performance_df

fn = "runs/logs.parquet"
df = pd.read_parquet(fn)
df = normalize_logs(df)
if 'set' not in df.columns:
    df["set"] = '0'
perf = get_interpolated_performance_df(df)
# Out:
# [11:34:42] INFO     Start normalization...                                                       ]8;id=675533;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=516038;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py#357\357]8;;\
#            INFO     Normalize n_trials...                                                        ]8;id=922390;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=685571;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py#358\358]8;;\
#            INFO     Normalize cost...                                                            ]8;id=214300;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=956249;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py#360\360]8;;\
#            INFO     Calc normalized incumbent cost...                                            ]8;id=803471;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=713175;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py#369\369]8;;\
#            INFO     Normalize time...                                                            ]8;id=83381;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=634835;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py#375\375]8;;\
#            INFO     Done.                                                                        ]8;id=651640;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=557748;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py#378\378]8;;\
#            INFO     Create dataframe for neat plotting by aligning x-axis / interpolating        ]8;id=186839;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=461260;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/gather_data.py#432\432]8;;\
#                     budget.

# %%
from carps.analysis.plot_ranking import plot_ranking
from carps.analysis.utils import setup_seaborn
import importlib
import carps
import carps.analysis
importlib.reload(carps)
importlib.reload(carps.analysis)
importlib.reload(carps.analysis.plot_ranking)
from carps.analysis.plot_ranking import plot_ranking

setup_seaborn()

for (scenario, set_id), gdf in df.groupby(by=["scenario", "set"]):
    print(scenario, set_id)
    plot_ranking(gdf=gdf, scenario=scenario, set_id=set_id)
# Out:
# multi-objective 0
# [11:34:46] INFO     Lost following experiments: Empty DataFrame                                 ]8;id=794193;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/run_autorank.py\run_autorank.py]8;;\:]8;id=410321;file:///home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/run_autorank.py#113\113]8;;\
#                     Columns: [HPI-ParEGO-50-quantile, HPI-ParEGO-top-hps, SMAC3-MO]
#                     Index: []
# Rejecting null hypothesis that data is normal for column HPI-ParEGO-50-quantile (p=0.000259<0.016667)
# Rejecting null hypothesis that data is normal for column HPI-ParEGO-top-hps (p=0.000206<0.016667)
# Rejecting null hypothesis that data is normal for column SMAC3-MO (p=0.001069<0.016667)
# Using Friedman test as omnibus test
# Fail to reject null hypothesis that there is no difference between the distributions (p=0.703736)
#                         meanrank    median       mad ci_lower  ci_upper  \
# HPI-ParEGO-top-hps          1.85  0.002148  0.002148      0.0  0.159211
# HPI-ParEGO-50-quantile      1.95  0.003828  0.003828      0.0  0.187524
# SMAC3-MO                    2.20  0.002140   0.00214      0.0  0.035399
#
#                        effect_size   magnitude
# HPI-ParEGO-top-hps             0.0  negligible
# HPI-ParEGO-50-quantile   -0.365117       small
# SMAC3-MO                  0.002387  negligible
# /home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/run_autorank.py:322: UserWarning: Result is not significant and results of the plot may be misleading!
#   warnings.warn("Result is not significant and results of the plot may be misleading!")
# /home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/autorank/_util.py:432: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(sorted_ranks[i] - sorted_ranks[j]) <= critical_difference:
# /home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/run_autorank.py:233: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   [(rankpos(sorted_ranks[i]), cline), (rankpos(sorted_ranks[i]), chei), (textspace - 0.1, chei)],
# /home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/run_autorank.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   [(rankpos(sorted_ranks[i]), cline), (rankpos(sorted_ranks[i]), chei), (textspace + scalewidth + 0.1, chei)],
# /home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/carps/analysis/run_autorank.py:263: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plot_line([(rankpos(sorted_ranks[l]) - side, start), (rankpos(sorted_ranks[r]) + side, start)], linewidth=2.5)
# /home/dath04/miniconda3/envs/carps/lib/python3.10/site-packages/autorank/_util.py:432: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(sorted_ranks[i] - sorted_ranks[j]) <= critical_difference:

# %%
import importlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import carps.analysis.performance_over_time

importlib.reload(carps)
importlib.reload(carps.analysis)
importlib.reload(carps.analysis.performance_over_time)
from carps.analysis.performance_over_time import plot_performance_over_time, setup_seaborn, savefig, get_color_palette

setup_seaborn()


lineplot_kwargs = {"linewidth": 3}
for gid, gdf in perf.groupby(by=["scenario", "set"]):
    print(gid)
    fig, ax = plot_performance_over_time(
        df=gdf,
        x="n_trials_norm",
        y="trial_value__cost_inc_norm",
        hue="optimizer_id",
        figure_filename=f"figures/perf_over_time/performance_over_time_{gid}_trials",
        figsize=(6,4),
        title="Performance over Time (Normalized)",
        **lineplot_kwargs
    )
    plt.show()
# Out:
# ('multi-objective', '0')

# %%
setup_seaborn()

perf_mini = perf[perf['optimizer_id']!='HPI-ParEGO-50-quantile']

lineplot_kwargs = {"linewidth": 3}
for gid, gdf in perf_mini.groupby(by=["scenario", "set"]):
    print(gid)
    fig, ax = plot_performance_over_time(
        df=gdf,
        x="n_trials_norm",
        y="trial_value__cost_inc_norm",
        hue="optimizer_id",
        figure_filename=f"figures/perf_over_time/performance_over_time_{gid}_trials",
        figsize=(6,4),
        title="Performance over Time (Normalized)",
        **lineplot_kwargs
    )
    plt.show()
# Out:
# ('multi-objective', '0')

# %%
from pathlib import Path

result_path = Path("figures/results")  # in overleaf

tex_path = Path("figures/latex")
tex_path.mkdir(exist_ok=True, parents=True)

figure_template = r"""
\begin{figure}[h]
    \centering
    \includegraphics[width=0.5\linewidth]{figures/results/critdiff/cdscenario_set_id.pdf}\hfill
    \includegraphics[width=0.5\linewidth]{figures/results/perf_over_time/performance_over_time_('scenario', 'set_id')_trials.pdf}\\
    \vspace{1mm}
    \includegraphics[width=\linewidth]{figures/results/ranking/final_per_combined_scenario_set_id.pdf}
    \caption{fig_caption}
    \label{fig_label}
\end{figure}
"""

table_template = r"""
Please find the results overview for the different scenarios and their subsets here:
\begin{table}[h]
\centering
\begin{tabular}{llr}
\toprule
Scenario & Subset & Link \\
\midrule
table_rows
\bottomrule
\end{tabular}
\end{table}
"""

table_row_template = "{scenario} & {set_id} & \\cref{{{fig_label}}}\\\\\n"

input_template = "\\input{{{latex_fn}}}\n"

complete_code = r"""
table_template

input_templates
"""

input_templates = ""
table_rows = ""
for (scenario, set_id), gdf in df.groupby(by=["scenario", "set"]):
    fig_caption = f"Scenario: {scenario}, set: {set_id}. Final Performance Overview"
    fig_label = f"fig:combinedperf_{scenario}_{set_id}"

    latex_str = figure_template
    latex_str = latex_str.replace("scenario", scenario)
    latex_str = latex_str.replace("set_id", set_id)
    latex_str = latex_str.replace("fig_caption", fig_caption)
    latex_str = latex_str.replace("fig_label", fig_label)

    latex_fn = tex_path / (fig_label.replace(":", "_") + ".tex")
    latex_fn.write_text(latex_str)

    print(latex_str)

    input_templates += input_template.format(latex_fn=result_path / "latex" / latex_fn.name[:-len(".tex")])
    table_rows += table_row_template.format(scenario=scenario, set_id=set_id, fig_label=fig_label)

complete_code = complete_code.replace("input_templates", input_templates)

table = table_template.replace("table_rows", table_rows)
complete_code = complete_code.replace("table_template", table)

description_fn = tex_path / "results.tex"
description_fn.write_text(complete_code)
print(complete_code)
# Out:
# \begin{figure}[h]
#     \centering
#     \includegraphics[width=0.5\linewidth]{figures/results/critdiff/cdmulti-objective_0.pdf}\hfill
#     \includegraphics[width=0.5\linewidth]{figures/results/perf_over_time/performance_over_time_('multi-objective', '0')_trials.pdf}\\
#     \vspace{1mm}
#     \includegraphics[width=\linewidth]{figures/results/ranking/final_per_combined_multi-objective_0.pdf}
#     \caption{Scenario: multi-objective, set: 0. Final Performance Overview}
#     \label{fig:combinedperf_multi-objective_0}
# \end{figure}
#
#
#
# Please find the results overview for the different scenarios and their subsets here:
# \begin{table}[h]
# \centering
# \begin{tabular}{llr}
# \toprule
# Scenario & Subset & Link \\
# \midrule
# multi-objective & 0 & \cref{fig:combinedperf_multi-objective_0}\\
#
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# \input{figures/results/latex/fig_combinedperf_multi-objective_0}
