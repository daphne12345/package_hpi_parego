# %%
import os

# Define the root directory where the problems are located
ROOT_DIR = "/home/daphne/Downloads/outputs/runs_8/"  # Change this to your actual path
TARGET_STRING = "HPI-ParEGO-50-quantile"
REPLACEMENT_STRING = "cs_adjust_t_fanova_constant_t_adjust_prev_t_default_t"

# Walk through the directory structure
for root, dirs, files in os.walk(ROOT_DIR):
    for file in files:
        if file == "config.yaml":
            config_path = os.path.join(root, file)
            
            # Read and replace content
            with open(config_path, "r") as f:
                content = f.read()
            
            new_content = content.replace(TARGET_STRING, REPLACEMENT_STRING)
            
            # Write back only if there was a change
            if new_content != content:
                with open(config_path, "w") as f:
                    f.write(new_content)
                print(f"Updated: {config_path}")

print("Replacement complete.")
# Out:
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart_rotated/0/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart_rotated/2/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart_rotated/3/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart_rotated/1/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart_rotated/4/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart/0/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart/2/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart/3/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart/1/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/sympart/4/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/omnitest/0/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/omnitest/2/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/omnitest/3/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/omnitest/1/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/omnitest/4/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/kursawe/0/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/kursawe/2/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/kursawe/3/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/kursawe/1/.hydra/config.yaml
# Updated: /home/daphne/Downloads/outputs/runs_8/HPI-ParEGO-50-quantile/Pymoo/Pymoo/MO/kursawe/4/.hydra/config.yaml
# Replacement complete.

# %%
import pandas as pd
from carps.analysis.gather_data import normalize_logs, get_interpolated_performance_df

fn = "/home/daphne/Downloads/outputs/hypershap/logs.parquet"
df = pd.read_parquet(fn)
df = normalize_logs(df)
if 'set' not in df.columns:
    df["set"] = '0'
perf = get_interpolated_performance_df(df)
# Out:
# [09:45:35] INFO     Start normalization...                                                       ]8;id=722079;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=655777;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py#357\357]8;;\
#            INFO     Normalize n_trials...                                                        ]8;id=113565;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=758097;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py#358\358]8;;\
#            INFO     Normalize cost...                                                            ]8;id=609690;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=460544;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py#360\360]8;;\
#            INFO     Calc normalized incumbent cost...                                            ]8;id=771162;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=79446;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py#369\369]8;;\
#            INFO     Normalize time...                                                            ]8;id=326824;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=891924;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py#375\375]8;;\
# [09:45:36] INFO     Done.                                                                        ]8;id=275836;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=603628;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py#378\378]8;;\
#            INFO     Create dataframe for neat plotting by aligning x-axis / interpolating        ]8;id=993512;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py\gather_data.py]8;;\:]8;id=276573;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/gather_data.py#432\432]8;;\
#                     budget.

# %%
from carps.analysis.plot_ranking import plot_ranking
from carps.analysis.utils import setup_seaborn
import importlib
import carps
import carps.analysis
importlib.reload(carps)
importlib.reload(carps.analysis)
importlib.reload(carps.analysis.plot_ranking)
from carps.analysis.plot_ranking import plot_ranking

setup_seaborn()

for (scenario, set_id), gdf in df.groupby(by=["scenario", "set"]):
    print(scenario, set_id)
    plot_ranking(gdf=gdf, scenario=scenario, set_id=set_id)
# Out:
# multi-objective 0
# [09:45:38] INFO     Lost following experiments: Empty DataFrame                                 ]8;id=752162;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/run_autorank.py\run_autorank.py]8;;\:]8;id=233328;file:///home/daphne/Code/hpi_parego/CARP-S/carps/analysis/run_autorank.py#113\113]8;;\
#                     Columns: [cs_adjust_f_hypershap_constant_t_adjust_prev_t_default_f,
#                     cs_adjust_f_hypershap_constant_t_adjust_prev_t_default_t,
#                     cs_adjust_t_hypershap_constant_f_adjust_prev_f_default_f,
#                     cs_adjust_t_hypershap_constant_t_adjust_prev_f_default_f]
#                     Index: []
# Fail to reject null hypothesis that data is normal for column cs_adjust_f_hypershap_constant_t_adjust_prev_t_default_f (p=0.055666>=0.012500)
# Rejecting null hypothesis that data is normal for column cs_adjust_f_hypershap_constant_t_adjust_prev_t_default_t (p=0.010787<0.012500)
# Rejecting null hypothesis that data is normal for column cs_adjust_t_hypershap_constant_f_adjust_prev_f_default_f (p=0.001599<0.012500)
# Rejecting null hypothesis that data is normal for column cs_adjust_t_hypershap_constant_t_adjust_prev_f_default_f (p=0.002191<0.012500)
# Using Friedman test as omnibus test
# Fail to reject null hypothesis that there is no difference between the distributions (p=0.212290)
#                                                     meanrank    median  \
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...      1.75  0.003224
# cs_adjust_t_hypershap_constant_t_adjust_prev_f_...      2.00  0.000905
# cs_adjust_t_hypershap_constant_f_adjust_prev_f_...      2.75  0.000502
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...      3.50  0.010353
#
#                                                          mad  ci_lower  \
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...  0.003174   0.00003
# cs_adjust_t_hypershap_constant_t_adjust_prev_f_...  0.000864  0.000033
# cs_adjust_t_hypershap_constant_f_adjust_prev_f_...   0.00032   0.00015
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...  0.010282  0.000059
#
#                                                     ci_upper effect_size  \
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...  0.066622         0.0
# cs_adjust_t_hypershap_constant_t_adjust_prev_f_...   0.07983    0.672406
# cs_adjust_t_hypershap_constant_f_adjust_prev_f_...   0.06916    0.813913
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...   0.09938   -0.632009
#
#                                                      magnitude
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...  negligible
# cs_adjust_t_hypershap_constant_t_adjust_prev_f_...      medium
# cs_adjust_t_hypershap_constant_f_adjust_prev_f_...       large
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_...      medium
# /home/daphne/Code/hpi_parego/CARP-S/carps/analysis/run_autorank.py:323: UserWarning: Result is not significant and results of the plot may be misleading!
#   warnings.warn("Result is not significant and results of the plot may be misleading!")
# /home/daphne/Code/hpi_parego/CARP-S/carps/analysis/run_autorank.py:233: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   [(rankpos(sorted_ranks[i]), cline), (rankpos(sorted_ranks[i]), chei), (textspace - 0.1, chei)],
# /home/daphne/Code/hpi_parego/CARP-S/carps/analysis/run_autorank.py:241: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   [(rankpos(sorted_ranks[i]), cline), (rankpos(sorted_ranks[i]), chei), (textspace + scalewidth + 0.1, chei)],
# /home/daphne/Code/hpi_parego/CARP-S/carps/analysis/run_autorank.py:263: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plot_line([(rankpos(sorted_ranks[l]) - side, start), (rankpos(sorted_ranks[r]) + side, start)], linewidth=2.5)
# /home/daphne/Code/hpi_parego/CARP-S/carps/analysis/run_autorank.py:340: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import importlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import carps.analysis.performance_over_time

importlib.reload(carps)
importlib.reload(carps.analysis)
importlib.reload(carps.analysis.performance_over_time)
from carps.analysis.performance_over_time import plot_performance_over_time, setup_seaborn, savefig, get_color_palette

setup_seaborn()


lineplot_kwargs = {"linewidth": 3}
for gid, gdf in perf.groupby(by=["scenario", "set"]):
    print(gid)
    fig, ax = plot_performance_over_time(
        df=gdf,
        x="n_trials_norm",
        y="trial_value__cost_inc_norm",
        hue="optimizer_id",
        figure_filename=f"figures/perf_over_time/performance_over_time_{gid}_trials",
        figsize=(6,4),
        title="Performance over Time (Normalized)",
        **lineplot_kwargs
    )
    plt.show()
# Out:
# ('multi-objective', '0')

# %%
perf.groupby(by=["optimizer_id"]).apply(lambda x: x.loc[x['n_trials_norm'].idxmax()]['trial_value__cost_inc_norm']).sort_values()
# Out:
# /tmp/ipykernel_20330/52948133.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   perf.groupby(by=["optimizer_id"]).apply(lambda x: x.loc[x['n_trials_norm'].idxmax()]['trial_value__cost_inc_norm']).sort_values()
# optimizer_id
# cs_adjust_t_hypershap_constant_f_adjust_prev_f_default_f    0.000000
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_default_t    0.002808
# cs_adjust_f_hypershap_constant_t_adjust_prev_t_default_f    0.060669
# cs_adjust_t_hypershap_constant_t_adjust_prev_f_default_f    0.078203
# dtype: float64

# %%
setup_seaborn()

perf_mini = perf[perf['optimizer_id']!='HPI-ParEGO-50-quantile']

lineplot_kwargs = {"linewidth": 3}
for gid, gdf in perf_mini.groupby(by=["scenario", "set"]):
    print(gid)
    fig, ax = plot_performance_over_time(
        df=gdf,
        x="n_trials_norm",
        y="trial_value__cost_inc_norm",
        hue="optimizer_id",
        figure_filename=f"figures/perf_over_time/performance_over_time_{gid}_trials",
        figsize=(6,4),
        title="Performance over Time (Normalized)",
        **lineplot_kwargs
    )
    plt.show()
# Out:
# ('multi-objective', '0')

# %%
from pathlib import Path

result_path = Path("figures/results")  # in overleaf

tex_path = Path("figures/latex")
tex_path.mkdir(exist_ok=True, parents=True)

figure_template = r"""
\begin{figure}[h]
    \centering
    \includegraphics[width=0.5\linewidth]{figures/results/critdiff/cdscenario_set_id.pdf}\hfill
    \includegraphics[width=0.5\linewidth]{figures/results/perf_over_time/performance_over_time_('scenario', 'set_id')_trials.pdf}\\
    \vspace{1mm}
    \includegraphics[width=\linewidth]{figures/results/ranking/final_per_combined_scenario_set_id.pdf}
    \caption{fig_caption}
    \label{fig_label}
\end{figure}
"""

table_template = r"""
Please find the results overview for the different scenarios and their subsets here:
\begin{table}[h]
\centering
\begin{tabular}{llr}
\toprule
Scenario & Subset & Link \\
\midrule
table_rows
\bottomrule
\end{tabular}
\end{table}
"""

table_row_template = "{scenario} & {set_id} & \\cref{{{fig_label}}}\\\\\n"

input_template = "\\input{{{latex_fn}}}\n"

complete_code = r"""
table_template

input_templates
"""

input_templates = ""
table_rows = ""
for (scenario, set_id), gdf in df.groupby(by=["scenario", "set"]):
    fig_caption = f"Scenario: {scenario}, set: {set_id}. Final Performance Overview"
    fig_label = f"fig:combinedperf_{scenario}_{set_id}"

    latex_str = figure_template
    latex_str = latex_str.replace("scenario", scenario)
    latex_str = latex_str.replace("set_id", set_id)
    latex_str = latex_str.replace("fig_caption", fig_caption)
    latex_str = latex_str.replace("fig_label", fig_label)

    latex_fn = tex_path / (fig_label.replace(":", "_") + ".tex")
    latex_fn.write_text(latex_str)

    print(latex_str)

    input_templates += input_template.format(latex_fn=result_path / "latex" / latex_fn.name[:-len(".tex")])
    table_rows += table_row_template.format(scenario=scenario, set_id=set_id, fig_label=fig_label)

complete_code = complete_code.replace("input_templates", input_templates)

table = table_template.replace("table_rows", table_rows)
complete_code = complete_code.replace("table_template", table)

description_fn = tex_path / "results.tex"
description_fn.write_text(complete_code)
print(complete_code)
# Out:
# \begin{figure}[h]
#     \centering
#     \includegraphics[width=0.5\linewidth]{figures/results/critdiff/cdmulti-objective_0.pdf}\hfill
#     \includegraphics[width=0.5\linewidth]{figures/results/perf_over_time/performance_over_time_('multi-objective', '0')_trials.pdf}\\
#     \vspace{1mm}
#     \includegraphics[width=\linewidth]{figures/results/ranking/final_per_combined_multi-objective_0.pdf}
#     \caption{Scenario: multi-objective, set: 0. Final Performance Overview}
#     \label{fig:combinedperf_multi-objective_0}
# \end{figure}
#
#
#
# Please find the results overview for the different scenarios and their subsets here:
# \begin{table}[h]
# \centering
# \begin{tabular}{llr}
# \toprule
# Scenario & Subset & Link \\
# \midrule
# multi-objective & 0 & \cref{fig:combinedperf_multi-objective_0}\\
#
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# \input{figures/results/latex/fig_combinedperf_multi-objective_0}
